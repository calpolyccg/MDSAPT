# %% [markdown]
# #Optimizer Methods Testing
#
# This is notebook for testing the workflow of the optimizer object in MDSAPT. Optimizer was developed to solve the issue of residues having an unbalanced spin when drawn directly from protein backbone. It does this over a few steps addressing the different issues.

# %%
import os

import numpy as np

import MDAnalysis as mda

from pdbfixer import PDBFixer

from simtk.openmm.app import PDBFile

import nglview as nv

from mdsapt.reader import InputReader
# Out:
# 2021-12-13 11:10:09,110 MDSAPT       INFO     MDSAPT 0+untagged.30.g1cdfbae.dirty starting
# 2021-12-13 11:10:09,112 MDSAPT       INFO     Copyright (c) 2021 Alia Lescoulie
# 2021-12-13 11:10:09,112 MDSAPT       INFO     Released under MIT Licence

# %%
In = InputReader(os.path.join(os.getcwd(), 'mdsapt', 'tests', 'testing_resources', 'test_input.yaml'))

unv = mda.Universe(In.top_path, In.trj_path)
# Out:
# 'pH' Error in trajectory settings

# %% [markdown]
# ##1. Loading the Residue
#
# In this case ARG is the residue. Both the amino and carboxyl side of the residue are missing protons.

# %%
# Selection prior to fixing

res = unv.select_atoms('resid 2')

nv.show_mdanalysis(res)
# Out:
# NGLWidget(max_frame=97)

# %% [markdown]
# ##2. Replacing missing Amino Protons
# The file is loaded into PDBFixer from opennm and amino protons are reattached.

# %%
res.write('resid.pdb', file_format='PDB') # Saving residue
fixer = PDBFixer(filename='resid.pdb')
fixer.findMissingResidues()
fixer.findMissingAtoms()
fixer.addMissingHydrogens(7) # Adding protons at pH value
PDBFile.writeFile(fixer.topology, fixer.positions, open('resid_fixed.pdb', 'w'))


res_fixed = mda.Universe('resid_fixed.pdb')
resid: mda.AtomGroup = res_fixed.select_atoms("resname *")
resid.guess_bonds()
nv.show_mdanalysis(resid)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'tempfactors' Using default value of '0.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1124: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# NGLWidget()

# %% [markdown]
# ##3. Adding New Proton
#
# The carbon on the carboxyl end of the residue only has three bonds when removed from the backbone. Rather than adding a hydroxyl group, a proton is added to the end as a 4th bond.

# %%
bkbone_fixed = mda.Universe('resid_fixed.pdb') # Load PDBRepair segid
bkbone_resid = bkbone_fixed.select_atoms("backbone") # Load backbone
ha = bkbone_fixed.select_atoms('name HA') # Remove proton on Alpha carbon
bkbone_resid = bkbone_resid - ha # Remove proton on Alpha carbon
carbon = bkbone_resid.select_atoms('name C') 
pos = carbon.atoms[0].position # Get postion of end carbon
h = mda.Universe.empty(n_atoms=bkbone_resid.n_atoms + 1, trajectory=True)
h.add_TopologyAttr("masses", [x for x in bkbone_resid.masses] + [1])
h.add_TopologyAttr("name", [x for x in bkbone_resid.names] + ['H'])
bkbone_pos = bkbone_resid.positions
h.atoms.positions = np.row_stack((bkbone_pos, np.array([pos[0] - np.cos(np.pi/6), pos[1] - np.sin(np.pi/6), pos[2]])))
nv.show_mdanalysis(h)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:433: UserWarning: Residues specified but no atom_resindex given.  All atoms will be placed in first Residue.
#   warnings.warn(
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:439: UserWarning: Segments specified but no segment_resindex given.  All residues will be placed in first Segment
#   warnings.warn(
# NGLWidget()

# %% [markdown]
# ##4. Optimizing New Bond
#
# Psi4 is employed to optimize the length of the newly added C-H bond.

# %%
import psi4
coords: str = ''
freeze_list = ''
opt_settings: dict = {'reference': 'rhf'} # Psi4 settings

# Getting coords and settings
for n in range(len(h.atoms)):
    atom = h.atoms[n]
    coords += f"\n{atom.name[0]} {atom.position[0]} {atom.position[1]} {atom.position[1]}"
    if not atom.name == 'H':
        freeze_list += f"\n{n + 1} xyz" # Freezing bonds besides H
print(freeze_list)
print(coords)

mol = psi4.geometry(coords)
# Out:
# 1 xyz
# 2 xyz
# 3 xyz
# 4 xyz
#
# N 11.840999603271484 6.642000198364258 6.642000198364258
# C 11.414999961853027 5.434000015258789 5.434000015258789
# C 10.770999908447266 5.855000019073486 5.855000019073486
# O 11.35200023651123 6.664000034332275 6.664000034332275
# H 9.904974937438965 5.355000019073486 5.355000019073486

# %%
psi4.set_memory('8GB')
psi4.set_options(opt_settings)
psi4.optimize('scf/dz', freeze_list=freeze_list, opt_coordinates='cartesian', molecule=mol)
# Out:
#   Memory set to   7.451 GiB by Python driver.
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:17 2021
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.659500635047    -0.632000840131     0.000000000000    14.003074004430
#          C           -1.082113530549    -0.327567474519     0.000000000000    12.000000000000
#          C           -0.318932910870     0.549023162787     0.000000000000    12.000000000000
#          O            0.532036269705     0.294096327414     0.000000000000    15.994914619570
#          H           -0.925114558717     1.476883964457     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      1.24112  B =      0.61863  C =      0.41285 [cm^-1]
#   Rotational constants: A =  37207.83189  B =  18546.11178  C =  12376.89325 [MHz]
#   Nuclear repulsion =  126.708873893561801
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: (DZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   258 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 2-3 entry C          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 4   entry O          line   318 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 5   entry H          line    18 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.37161.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.007 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.2268
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 4.6703441207E-03.
#   Reciprocal condition number of the overlap matrix is 8.1758763895E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        34      34      12      12      12       0
#      A"         8       8       2       2       2       0
#    -------------------------------------------------------
#     Total      42      42      14      14      14       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -204.14320075278076   -2.04143e+02   7.14251e-10
#    @DF-RHF iter   1:  -204.14320075278090   -1.42109e-13   3.00232e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap   -20.847657     2Ap   -15.708778     3Ap   -11.351333
#        4Ap   -11.284170     5Ap    -2.165717     6Ap    -1.476492
#        7Ap    -1.208553     1App   -1.076937     8Ap    -0.988019
#        9Ap    -0.733933    10Ap    -0.614111    11Ap    -0.459782
#        2App   -0.423475    12Ap    -0.368238
#
#     Virtual:
#
#        3App    0.027724    13Ap     0.155944    14Ap     0.254668
#        4App    0.259890    15Ap     0.287098    16Ap     0.381101
#       17Ap     0.398071     5App    0.431166    18Ap     0.443494
#       19Ap     0.588228     6App    0.603470    20Ap     0.614549
#        7App    0.658617    21Ap     0.746555    22Ap     0.802310
#       23Ap     0.940029     8App    0.941871    24Ap     1.081887
#       25Ap     1.221512    26Ap     1.315015    27Ap     1.497630
#       28Ap     1.672704    29Ap     1.827843    30Ap     1.944121
#       31Ap    23.755271    32Ap    24.167834    33Ap    33.073693
#       34Ap    43.336084
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [    12,    2 ]
#
#   @DF-RHF Final Energy:  -204.14320075278090
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            126.7088738935618011
#     One-Electron Energy =                -524.2897609699153918
#     Two-Electron Energy =                 193.4376863235726773
#     Total Energy =                       -204.1432007527808992
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -0.8666      Y:     1.3878      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     1.5297      Y:    -0.2471      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.6631      Y:     1.1407      Z:     0.0000     Total:     1.3194
#
#   Dipole Moment: [D]
#      X:     1.6853      Y:     2.8993      Z:     0.0000     Total:     3.3535
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:17 2021
# Module time:
# 	user time   =       0.31 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      43.96 seconds =       0.73 minutes
# 	system time =       2.69 seconds =       0.04 minutes
# 	total time  =        224 seconds =       3.73 minutes
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:17 2021
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.659500635047    -0.632000840131     0.000000000000    14.003074004430
#          C           -1.082113530549    -0.327567474519     0.000000000000    12.000000000000
#          C           -0.318932910870     0.549023162787     0.000000000000    12.000000000000
#          O            0.532036269705     0.294096327414     0.000000000000    15.994914619570
#          H           -0.925114558717     1.476883964457     0.000000000000     1.007825032230
#
#   Nuclear repulsion =  126.708873893561801
#
#   ==> Basis Set <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.408360599187     1.472994617102     0.000000000000
#        2        0.354452888723     0.281291876375     0.000000000000
#        3        1.961701629281    -1.024585877825     0.000000000000
#        4       -1.863347701013    -0.729870019227     0.000000000000
#        5       -0.044446217801     0.000169403577     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:17 2021
# Module time:
# 	user time   =       0.17 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      44.13 seconds =       0.74 minutes
# 	system time =       2.70 seconds =       0.05 minutes
# 	total time  =        224 seconds =       3.73 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Internal coordinates to be generated automatically.
# 	Detected frag 1 with atoms:  1 2 3 4 5
# 	---Fragment 1 Bond Connectivity---
# 	 1 : 2 3 4
# 	 2 : 1 3 4
# 	 3 : 1 2 4 5
# 	 4 : 1 2 3
# 	 5 : 3
#
# 	---Fragment 1 Geometry and Gradient---
# 	 N           1.2462755798       -1.1943084989        0.0000000000
# 	 C          -2.0448982094       -0.6190128144        0.0000000000
# 	 C          -0.6026958539        1.0375034142        0.0000000000
# 	 O           1.0054028386        0.5557615133        0.0000000000
# 	 H          -1.7482131506        2.7909062119        0.0000000000
# 	            -0.4083605992        1.4729946171        0.0000000000
# 	             0.3544528887        0.2812918764        0.0000000000
# 	             1.9617016293       -1.0245858778        0.0000000000
# 	            -1.8633477010       -0.7298700192        0.0000000000
# 	            -0.0444462178        0.0001694036        0.0000000000
#
# 	Previous optimization step data not found.  Starting new optimization.
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.341076	       1.768021
# 	 R(1,3)           =         2.898220	       1.533672
# 	 R(1,4)           =         1.766569	       0.934828
# 	 R(2,3)           =         2.196359	       1.162263
# 	 R(2,4)           =         3.268705	       1.729724
# 	 R(3,4)           =         1.678707	       0.888333
# 	 R(3,5)           =         2.094429	       1.108324
# 	 B(1,2,3)         =         1.027501	      58.871497
# 	 B(1,2,4)         =         0.540677	      30.978488
# 	 B(1,3,2)         =         1.408203	      80.684062
# 	 B(1,3,4)         =         0.587875	      33.682780
# 	 B(1,3,5)         =         3.028435	     173.516568
# 	 B(1,4,2)         =         1.339948	      76.773341
# 	 B(1,4,3)         =         1.998637	     114.513489
# 	 B(2,1,3)         =         0.705889	      40.444440
# 	 B(2,1,4)         =         1.260968	      72.248171
# 	 B(2,3,4)         =         1.996078	     114.366842
# 	 B(2,3,5)         =         1.846547	     105.799370
# 	 B(2,4,3)         =         0.658690	      37.740149
# 	 B(3,1,4)         =         0.555080	      31.803731
# 	 B(3,2,4)         =         0.486825	      27.893009
# 	 B(4,3,5)         =         2.440560	     139.833788
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,3,5)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,1,3,5)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -204.1432007528
#
# 	Generating empirical Hessian (Schlegel '84) for each fragment.
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.51011
# 	Projected energy change by RFO approximation:        -0.6290276039
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.768021     2.218491     0.079209     1.847231
# 	    2 R(1,3)          =      1.533672     7.545898     0.153361     1.687033
# 	    3 R(1,4)          =      0.934828     4.328504     0.099476     1.034304
# 	    4 R(2,3)          =      1.162263    -0.462451     0.056425     1.218688
# 	    5 R(2,4)          =      1.729724     4.459637     0.107760     1.837484
# 	    6 R(3,4)          =      0.888333     7.538927     0.108868     0.997201
# 	    7 R(3,5)          =      1.108324    -0.201445    -0.011548     1.096776
# 	    8 B(1,2,3)        =     58.871497     0.025280     4.023654    62.895151
# 	    9 B(1,2,4)        =     30.978488     0.007639     1.624267    32.602755
# 	   10 B(1,3,2)        =     80.684062    -0.016138    -3.598786    77.085277
# 	   11 B(1,3,4)        =     33.682780     0.006310     0.882360    34.565140
# 	   12 B(1,3,5)        =    173.516568     0.005511    -0.064672   173.451896
# 	   13 B(1,4,2)        =     76.773341    -0.016056    -2.556491    74.216850
# 	   14 B(1,4,3)        =    114.513489    -0.023869    -2.239452   112.274037
# 	   15 B(2,1,3)        =     40.444440    -0.009142    -0.424868    40.019572
# 	   16 B(2,1,4)        =     72.248171     0.008417     0.932224    73.180395
# 	   17 B(2,3,4)        =    114.366842    -0.009828    -2.716426   111.650416
# 	   18 B(2,3,5)        =    105.799370     0.010627     3.663457   109.462827
# 	   19 B(2,4,3)        =     37.740149    -0.007813     0.317038    38.057187
# 	   20 B(3,1,4)        =     31.803731     0.017559     1.357092    33.160823
# 	   21 B(3,2,4)        =     27.893009     0.017641     2.399387    30.292396
# 	   22 B(4,3,5)        =    139.833788    -0.000799    -0.947032   138.886756
# 	   23 D(1,2,3,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   24 D(1,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   25 D(1,2,4,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   26 D(1,3,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   27 D(1,3,4,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   28 D(1,4,2,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   29 D(1,4,3,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   30 D(1,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   31 D(2,1,3,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   32 D(2,1,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   33 D(2,1,4,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   34 D(2,3,1,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   35 D(2,4,1,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   36 D(2,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   37 D(3,1,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   38 D(3,2,1,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   39 D(4,1,3,5)      =      0.000000     0.000000     0.000000     0.000000
# 	   40 D(4,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   --------------------------------------------------------------------------------------------- ~
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp    ~
#   --------------------------------------------------------------------------------------------- ~
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o  ~
#   --------------------------------------------------------------------------------------------- ~
#       1    -204.14320075   -2.04e+02      9.16e-01      2.66e-01 o    2.90e-01      8.06e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    N     0.7000829011  -0.7127511224   0.0000000000
# 	    C    -1.1136505482  -0.3625632073   0.0000000000
# 	    C    -0.3628013085   0.5973466002   0.0000000000
# 	    O     0.5939141524   0.3160894279   0.0000000000
# 	    H    -0.9521692878   1.5223134363   0.0000000000
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N            0.688704533675    -0.702329372229     0.000000000000
#     C           -1.125028922777    -0.352141455748     0.000000000000
#     C           -0.374179680180     0.607768355519     0.000000000000
#     O            0.582535784537     0.326511182099     0.000000000000
#     H           -0.963547661772     1.532735195243     0.000000000000
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:17 2021
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.688704533675    -0.702329372229     0.000000000000    14.003074004430
#          C           -1.125028922777    -0.352141455748     0.000000000000    12.000000000000
#          C           -0.374179680180     0.607768355519     0.000000000000    12.000000000000
#          O            0.582535784537     0.326511182099     0.000000000000    15.994914619570
#          H           -0.963547661772     1.532735195243     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      1.04337  B =      0.55059  C =      0.36040 [cm^-1]
#   Rotational constants: A =  31279.49360  B =  16506.12733  C =  10804.57456 [MHz]
#   Nuclear repulsion =  116.849140080525359
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: (DZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   258 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 2-3 entry C          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 4   entry O          line   318 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 5   entry H          line    18 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.37161.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.007 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.3401
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 5.8342365139E-03.
#   Reciprocal condition number of the overlap matrix is 1.0682778846E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        34      34      12      12      12       0
#      A"         8       8       2       2       2       0
#    -------------------------------------------------------
#     Total      42      42      14      14      14       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -204.54536255687310   -2.04545e+02   2.68035e-02
#    @DF-RHF iter   1:  -204.72829901261898   -1.82936e-01   1.82394e-03 DIIS
#    @DF-RHF iter   2:  -204.73087621450276   -2.57720e-03   6.17168e-04 DIIS
#    @DF-RHF iter   3:  -204.73139128948330   -5.15075e-04   3.70709e-04 DIIS
#    @DF-RHF iter   4:  -204.73166465343314   -2.73364e-04   2.06918e-04 DIIS
#    @DF-RHF iter   5:  -204.73188371580559   -2.19062e-04   1.41486e-04 DIIS
#    @DF-RHF iter   6:  -204.73203604938590   -1.52334e-04   3.69930e-05 DIIS
#    @DF-RHF iter   7:  -204.73204316312930   -7.11374e-06   1.80140e-05 DIIS
#    @DF-RHF iter   8:  -204.73204379529318   -6.32164e-07   5.96391e-06 DIIS
#    @DF-RHF iter   9:  -204.73204390617437   -1.10881e-07   2.46835e-06 DIIS
#    @DF-RHF iter  10:  -204.73204392520324   -1.90289e-08   7.11314e-07 DIIS
#    @DF-RHF iter  11:  -204.73204392664655   -1.44331e-09   1.38866e-07 DIIS
#    @DF-RHF iter  12:  -204.73204392669498   -4.84306e-11   2.19328e-08 DIIS
#    @DF-RHF iter  13:  -204.73204392669589   -9.09495e-13   5.42143e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap   -20.793045     2Ap   -15.703825     3Ap   -11.322714
#        4Ap   -11.296717     5Ap    -2.000807     6Ap    -1.364038
#        7Ap    -1.137708     1App   -0.946811     8Ap    -0.926368
#        9Ap    -0.727192    10Ap    -0.644070    11Ap    -0.473816
#        2App   -0.409883    12Ap    -0.388211
#
#     Virtual:
#
#        3App    0.019480    13Ap     0.135078     4App    0.240808
#       14Ap     0.262926    15Ap     0.283917    16Ap     0.387202
#       17Ap     0.412244     5App    0.421446    18Ap     0.437283
#        6App    0.585094    19Ap     0.589032    20Ap     0.629282
#        7App    0.670244    21Ap     0.741635    22Ap     0.815093
#       23Ap     0.876221     8App    0.941921    24Ap     1.069254
#       25Ap     1.162371    26Ap     1.269105    27Ap     1.287136
#       28Ap     1.460976    29Ap     1.586698    30Ap     1.869286
#       31Ap    23.717733    32Ap    24.124575    33Ap    33.007660
#       34Ap    43.312838
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [    12,    2 ]
#
#   @DF-RHF Final Energy:  -204.73204392669589
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            116.8491400805253591
#     One-Electron Energy =                -506.8919549517062251
#     Two-Electron Energy =                 185.3107709444850002
#     Total Energy =                       -204.7320439266958942
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -0.9025      Y:     1.4405      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     1.4029      Y:    -0.3187      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:     0.5004      Y:     1.1218      Z:     0.0000     Total:     1.2283
#
#   Dipole Moment: [D]
#      X:     1.2718      Y:     2.8514      Z:     0.0000     Total:     3.1221
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:18 2021
# Module time:
# 	user time   =       0.35 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      44.49 seconds =       0.74 minutes
# 	system time =       2.73 seconds =       0.05 minutes
# 	total time  =        225 seconds =       3.75 minutes
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:18 2021
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.688704533675    -0.702329372229     0.000000000000    14.003074004430
#          C           -1.125028922777    -0.352141455748     0.000000000000    12.000000000000
#          C           -0.374179680180     0.607768355519     0.000000000000    12.000000000000
#          O            0.582535784537     0.326511182099     0.000000000000    15.994914619570
#          H           -0.963547661772     1.532735195243     0.000000000000     1.007825032230
#
#   Nuclear repulsion =  116.849140080525359
#
#   ==> Basis Set <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.192262103637     0.717353810809     0.000000000000
#        2        0.222776298271     0.172582359214     0.000000000000
#        3        1.034291913755    -0.531279452565     0.000000000000
#        4       -1.024781198154    -0.358983845049     0.000000000000
#        5       -0.040024910235     0.000327127591     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:18 2021
# Module time:
# 	user time   =       0.16 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      44.65 seconds =       0.74 minutes
# 	system time =       2.74 seconds =       0.05 minutes
# 	total time  =        225 seconds =       3.75 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 N           1.3014629500       -1.3272101634        0.0000000000
# 	 C          -2.1259965473       -0.6654509088        0.0000000000
# 	 C          -0.7070971173        1.1485157397        0.0000000000
# 	 O           1.1008330911        0.6170167111        0.0000000000
# 	 H          -1.8208411896        2.8964497419        0.0000000000
# 	            -0.1922621036        0.7173538108        0.0000000000
# 	             0.2227762983        0.1725823592        0.0000000000
# 	             1.0342919138       -0.5312794526        0.0000000000
# 	            -1.0247811982       -0.3589838450        0.0000000000
# 	            -0.0400249102        0.0003271276        0.0000000000
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.490760	       1.847231
# 	 R(1,3)           =         3.188030	       1.687033
# 	 R(1,4)           =         1.954551	       1.034304
# 	 R(2,3)           =         2.302987	       1.218688
# 	 R(2,4)           =         3.472341	       1.837484
# 	 R(3,4)           =         1.884437	       0.997201
# 	 R(3,5)           =         2.072607	       1.096776
# 	 B(1,2,3)         =         1.097727	      62.895151
# 	 B(1,2,4)         =         0.569025	      32.602755
# 	 B(1,3,2)         =         1.345392	      77.085277
# 	 B(1,3,4)         =         0.603275	      34.565140
# 	 B(1,3,5)         =         3.027307	     173.451896
# 	 B(1,4,2)         =         1.295328	      74.216850
# 	 B(1,4,3)         =         1.959552	     112.274037
# 	 B(2,1,3)         =         0.698473	      40.019572
# 	 B(2,1,4)         =         1.277239	      73.180395
# 	 B(2,3,4)         =         1.948667	     111.650416
# 	 B(2,3,5)         =         1.910487	     109.462827
# 	 B(2,4,3)         =         0.664223	      38.057187
# 	 B(3,1,4)         =         0.578766	      33.160823
# 	 B(3,2,4)         =         0.528702	      30.292396
# 	 B(4,3,5)         =         2.424031	     138.886756
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,3,5)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,1,3,5)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -204.7320439267
#
# 	Energy change for the previous step:
# 		Projected    :        -0.6290276039
# 		Actual       :        -0.5888431739
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Steps to be used in Hessian update: 1
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.46496
# 	Projected energy change by RFO approximation:        -0.3146595369
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.847231     1.062466     0.041920     1.889151
# 	    2 R(1,3)          =      1.687033     3.780738     0.108262     1.795295
# 	    3 R(1,4)          =      1.034304     2.159677     0.088447     1.122751
# 	    4 R(2,3)          =      1.218688    -0.058203     0.055364     1.274052
# 	    5 R(2,4)          =      1.837484     2.588766     0.118690     1.956174
# 	    6 R(3,4)          =      0.997201     4.166111     0.107716     1.104917
# 	    7 R(3,5)          =      1.096776    -0.179471    -0.019319     1.077457
# 	    8 B(1,2,3)        =     62.895151     0.012261     2.960323    65.855474
# 	    9 B(1,2,4)        =     32.602755     0.003173     1.293020    33.895774
# 	   10 B(1,3,2)        =     77.085277    -0.008138    -3.299999    73.785277
# 	   11 B(1,3,4)        =     34.565140     0.003039     2.075190    36.640330
# 	   12 B(1,3,5)        =    173.451896     0.001960    -0.822183   172.629713
# 	   13 B(1,4,2)        =     74.216850    -0.008606    -4.438264    69.778586
# 	   14 B(1,4,3)        =    112.274037    -0.012595    -4.880758   107.393279
# 	   15 B(2,1,3)        =     40.019572    -0.004123     0.339676    40.359248
# 	   16 B(2,1,4)        =     73.180395     0.005432     3.145244    76.325639
# 	   17 B(2,3,4)        =    111.650416    -0.005099    -1.224809   110.425607
# 	   18 B(2,3,5)        =    109.462827     0.006178     4.122182   113.585009
# 	   19 B(2,4,3)        =     38.057187    -0.003989    -0.442494    37.614693
# 	   20 B(3,1,4)        =     33.160823     0.009556     2.805568    35.966391
# 	   21 B(3,2,4)        =     30.292396     0.009088     1.667303    31.959700
# 	   22 B(4,3,5)        =    138.886756    -0.001079    -2.897373   135.989383
# 	   23 D(1,2,3,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   24 D(1,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   25 D(1,2,4,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   26 D(1,3,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   27 D(1,3,4,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   28 D(1,4,2,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   29 D(1,4,3,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   30 D(1,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   31 D(2,1,3,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   32 D(2,1,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   33 D(2,1,4,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   34 D(2,3,1,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   35 D(2,4,1,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   36 D(2,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   37 D(3,1,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   38 D(3,2,1,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   39 D(4,1,3,5)      =      0.000000     0.000000     0.000000     0.000000
# 	   40 D(4,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   ---------------------------------------------------------------------------------------------
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp
#   ---------------------------------------------------------------------------------------------
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
#   ---------------------------------------------------------------------------------------------
#       2    -204.73204393   -5.89e-01      5.06e-01      1.40e-01 o    2.24e-01      7.35e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    N     0.7005718830  -0.7614754170   0.0000000000
# 	    C    -1.1529071902  -0.3960909961   0.0000000000
# 	    C    -0.4167501409   0.6437556537   0.0000000000
# 	    O     0.6511598789   0.3601876597   0.0000000000
# 	    H    -0.9735903727   1.5661669990   0.0000000000
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N            0.693148854610    -0.755086503349     0.000000000000
#     C           -1.160330225913    -0.389702081035     0.000000000000
#     C           -0.424173173768     0.650144572791     0.000000000000
#     O            0.643736850312     0.366576577745     0.000000000000
#     H           -0.981013407705     1.572555921727     0.000000000000
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:18 2021
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.693148854610    -0.755086503349     0.000000000000    14.003074004430
#          C           -1.160330225913    -0.389702081035     0.000000000000    12.000000000000
#          C           -0.424173173768     0.650144572791     0.000000000000    12.000000000000
#          O            0.643736850312     0.366576577745     0.000000000000    15.994914619570
#          H           -0.981013407705     1.572555921727     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      0.89336  B =      0.50636  C =      0.32318 [cm^-1]
#   Rotational constants: A =  26782.11004  B =  15180.32277  C =   9688.69171 [MHz]
#   Nuclear repulsion =  109.406951090470159
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#    => Loading Basis Set <=
#
#     Name: (DZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   258 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 2-3 entry C          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 4   entry O          line   318 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 5   entry H          line    18 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: DZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line    85 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 2-3 entry C          line    63 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 4   entry O          line   107 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#     atoms 5   entry H          line    12 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/dz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.37161.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.007 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.4535
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 6.9080682912E-03.
#   Reciprocal condition number of the overlap matrix is 1.3142583366E-03.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        34      34      12      12      12       0
#      A"         8       8       2       2       2       0
#    -------------------------------------------------------
#     Total      42      42      14      14      14       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -204.80556796570258   -2.04806e+02   1.95893e-02
#    @DF-RHF iter   1:  -205.01226401260851   -2.06696e-01   2.09573e-03 DIIS
#    @DF-RHF iter   2:  -205.01445749797102   -2.19349e-03   1.32344e-03 DIIS
#    @DF-RHF iter   3:  -205.01546034050006   -1.00284e-03   3.31645e-04 DIIS
#    @DF-RHF iter   4:  -205.01573062641967   -2.70286e-04   1.58923e-04 DIIS
#    @DF-RHF iter   5:  -205.01586302365669   -1.32397e-04   1.00056e-04 DIIS
#    @DF-RHF iter   6:  -205.01592158847677   -5.85648e-05   3.78130e-05 DIIS
#    @DF-RHF iter   7:  -205.01592925396315   -7.66549e-06   1.39955e-05 DIIS
#    @DF-RHF iter   8:  -205.01592987119460   -6.17231e-07   5.10405e-06 DIIS
#    @DF-RHF iter   9:  -205.01592996188180   -9.06872e-08   2.02033e-06 DIIS
#    @DF-RHF iter  10:  -205.01592997671531   -1.48335e-08   5.76949e-07 DIIS
#    @DF-RHF iter  11:  -205.01592997776226   -1.04694e-09   1.86053e-07 DIIS
#    @DF-RHF iter  12:  -205.01592997784891   -8.66578e-11   4.62367e-08 DIIS
#    @DF-RHF iter  13:  -205.01592997785153   -2.61480e-12   1.00937e-08 DIIS
# ...
#      X:    -0.2651      Y:     0.7833      Z:     0.0000     Total:     0.8270
#
#   Dipole Moment: [D]
#      X:    -0.6739      Y:     1.9910      Z:     0.0000     Total:     2.1019
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:28 2021
# Module time:
# Optimizer: Optimization complete!
# 	user time   =       0.32 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      54.17 seconds =       0.90 minutes
# 	system time =       3.36 seconds =       0.06 minutes
# 	total time  =        235 seconds =       3.92 minutes
#
# *** tstart() called on Alias-MBP
# *** at Mon Dec 13 14:27:28 2021
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            1.202666751483    -0.834343464544     0.000000000000    14.003074004430
#          C           -1.656463857768    -0.271350061996     0.000000000000    12.000000000000
#          C           -0.650312123551     0.597844377565     0.000000000000    12.000000000000
#          O            0.735414765323     0.382239515889     0.000000000000    15.994914619570
#          H           -0.915452682415     1.638729956691     0.000000000000     1.007825032230
#
#   Nuclear repulsion =   90.223947478242962
#
#   ==> Basis Set <==
#
#   Basis Set: DZ
#     Blend: DZ
#     Number of shells: 26
#     Number of basis functions: 42
#     Number of Cartesian functions: 42
#     Spherical Harmonics?: false
#     Max angular momentum: 1
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (DZ AUX)
#     Blend: DEF2-UNIVERSAL-JKFIT
#     Number of shells: 106
#     Number of basis functions: 384
#     Number of Cartesian functions: 384
#     Spherical Harmonics?: false
#     Max angular momentum: 4
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.000016601972     0.000028817872     0.000000000000
#        2        0.000056179384     0.000042032705     0.000000000000
#        3       -0.000046593904    -0.000056838994     0.000000000000
#        4       -0.000004508555    -0.000016298961     0.000000000000
#        5        0.000011525045     0.000002287379     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Dec 13 14:27:28 2021
# Module time:
# 	user time   =       0.15 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      54.32 seconds =       0.91 minutes
# 	system time =       3.37 seconds =       0.06 minutes
# 	total time  =        235 seconds =       3.92 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 N           2.2727107805       -1.5766806426        0.0000000000
# 	 C          -3.1302630279       -0.5127773013        0.0000000000
# 	 C          -1.2289118096        1.1297621392        0.0000000000
# 	 O           1.3897324951        0.7223279994        0.0000000000
# 	 H          -1.7299548506        3.0967508117        0.0000000000
# 	            -0.0000166020        0.0000288179        0.0000000000
# 	             0.0000561794        0.0000420327        0.0000000000
# 	            -0.0000465939       -0.0000568390        0.0000000000
# 	            -0.0000045086       -0.0000162990        0.0000000000
# 	             0.0000115250        0.0000022874        0.0000000000
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         5.506725	       2.914033
# 	 R(1,3)           =         4.425629	       2.341942
# 	 R(1,4)           =         2.462741	       1.303226
# 	 R(2,3)           =         2.512583	       1.329602
# 	 R(2,4)           =         4.685706	       2.479569
# 	 R(3,4)           =         2.650151	       1.402400
# 	 R(3,5)           =         2.029800	       1.074124
# 	 B(1,2,3)         =         0.906920	      51.962717
# 	 B(1,2,4)         =         0.461165	      26.422822
# 	 B(1,3,2)         =         1.771092	     101.476086
# 	 B(1,3,4)         =         0.503652	      28.857107
# 	 B(1,3,5)         =         2.478222	     141.991640
# 	 B(1,4,2)         =         1.670752	      95.727055
# 	 B(1,4,3)         =         2.091846	     119.853968
# 	 B(2,1,3)         =         0.463580	      26.561197
# 	 B(2,1,4)         =         1.009675	      57.850122
# 	 B(2,3,4)         =         2.274743	     130.333193
# 	 B(2,3,5)         =         2.033872	     116.532274
# 	 B(2,4,3)         =         0.421094	      24.126912
# 	 B(3,1,4)         =         0.546095	      31.288925
# 	 B(3,2,4)         =         0.445755	      25.539895
# 	 B(4,3,5)         =         1.974570	     113.134533
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,3,5)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,1,3,5)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -205.2510767984
#
# 	Energy change for the previous step:
# 		Projected    :        -0.0000007240
# 		Actual       :        -0.0000003763
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Steps to be used in Hessian update: 20 19
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.00025
# 	Projected energy change by RFO approximation:        -0.0000000071
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      2.914033     0.000096     0.000092     2.914125
# 	    2 R(1,3)          =      2.341942     0.000069     0.000042     2.341984
# 	    3 R(1,4)          =      1.303226     0.000134     0.000025     1.303252
# 	    4 R(2,3)          =      1.329602     0.000345     0.000029     1.329630
# 	    5 R(2,4)          =      2.479569     0.000165     0.000056     2.479625
# 	    6 R(3,4)          =      1.402400    -0.000073     0.000013     1.402412
# 	    7 R(3,5)          =      1.074124     0.000005     0.000003     1.074127
# 	    8 B(1,2,3)        =     51.962717     0.000000    -0.001536    51.961181
# 	    9 B(1,2,4)        =     26.422822     0.000000    -0.000417    26.422405
# 	   10 B(1,3,2)        =    101.476086    -0.000001     0.002031   101.478117
# 	   11 B(1,3,4)        =     28.857107     0.000000    -0.000184    28.856923
# 	   12 B(1,3,5)        =    141.991640     0.000001     0.001349   141.992989
# 	   13 B(1,4,2)        =     95.727055    -0.000001     0.001482    95.728537
# 	   14 B(1,4,3)        =    119.853968     0.000000     0.000753   119.854721
# 	   15 B(2,1,3)        =     26.561197     0.000001    -0.000495    26.560702
# 	   16 B(2,1,4)        =     57.850122     0.000000    -0.001064    57.849058
# 	   17 B(2,3,4)        =    130.333193    -0.000001     0.001847   130.335040
# 	   18 B(2,3,5)        =    116.532274    -0.000000    -0.003380   116.528894
# 	   19 B(2,4,3)        =     24.126912     0.000001    -0.000728    24.126184
# 	   20 B(3,1,4)        =     31.288925    -0.000000    -0.000569    31.288356
# 	   21 B(3,2,4)        =     25.539895    -0.000000    -0.001119    25.538776
# 	   22 B(4,3,5)        =    113.134533     0.000001     0.001533   113.136066
# 	   23 D(1,2,3,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   24 D(1,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   25 D(1,2,4,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   26 D(1,3,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   27 D(1,3,4,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   28 D(1,4,2,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   29 D(1,4,3,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   30 D(1,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   31 D(2,1,3,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   32 D(2,1,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   33 D(2,1,4,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   34 D(2,3,1,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   35 D(2,4,1,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   36 D(2,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   37 D(3,1,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   38 D(3,2,1,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   39 D(4,1,3,5)      =      0.000000     0.000000     0.000000     0.000000
# 	   40 D(4,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   ---------------------------------------------------------------------------------------------
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp
#   ---------------------------------------------------------------------------------------------
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
#   ---------------------------------------------------------------------------------------------
#      21    -205.25107680   -3.76e-07 *    4.19e-05 *    9.25e-06 o    1.74e-04 *    3.98e-05 o  ~
#   ---------------------------------------------------------------------------------------------
#
#
#   **** Optimization is complete! (in 21 steps) ****
#
#   ==> Optimization Summary <==
#
#   Measures of convergence in internal coordinates in au.
#   --------------------------------------------------------------------------------------------------------------- ~
#    Step         Total Energy             Delta E       MAX Force       RMS Force        MAX Disp        RMS Disp  ~
#   --------------------------------------------------------------------------------------------------------------- ~
#       1    -204.143200752781   -204.143200752781      0.91590637      0.26563582      0.28980943      0.08063534  ~
#       2    -204.732043926696     -0.588843173915      0.50567445      0.14005268      0.22429139      0.07346771  ~
#       3    -205.015929977852     -0.283886051156      0.27905238      0.07325499      0.17870704      0.05622876  ~
#       4    -205.128454953948     -0.112524976096      0.17355673      0.04269140      0.14765337      0.05135709  ~
#       5    -205.186160913276     -0.057705959328      0.10137609      0.02354511      0.14359785      0.04741269  ~
#       6    -205.213089912890     -0.026928999614      0.05548909      0.01260594      0.16536425      0.04301309  ~
#       7    -205.225213761645     -0.012123848755      0.02743044      0.00712917      0.20482815      0.04562279  ~
#       8    -205.232508536986     -0.007294775341      0.01586423      0.00472373      0.28707728      0.06052365  ~
#       9    -205.239217303768     -0.006708766782      0.01441878      0.00409053      0.36804736      0.07710804  ~
#      10    -205.245246566914     -0.006029263146      0.01246290      0.00413474      0.32753068      0.06960262  ~
#      11    -205.248589911445     -0.003343344531      0.01351599      0.00363737      0.16027316      0.03567243  ~
#      12    -205.249793935698     -0.001204024253      0.01096174      0.00292955      0.04431818      0.01465272  ~
#      13    -205.250397720515     -0.000603784817      0.01038163      0.00240267      0.03506173      0.01186551  ~
#      14    -205.250695739223     -0.000298018707      0.01001727      0.00206751      0.01677405      0.00580600  ~
#      15    -205.250818309390     -0.000122570167      0.00831014      0.00174399      0.02982690      0.00913244  ~
#      16    -205.250939580816     -0.000121271426      0.00533776      0.00130735      0.01010004      0.00281813  ~
#      17    -205.250978050278     -0.000038469462      0.00432658      0.00112616      0.01019252      0.00303643  ~
#      18    -205.251047294382     -0.000069244104      0.00259318      0.00064005      0.00938073      0.00263257  ~
#      19    -205.251074255264     -0.000026960882      0.00068838      0.00015809      0.00264217      0.00072881  ~
#      20    -205.251076422080     -0.000002166816      0.00024565      0.00005972      0.00130659      0.00045986  ~
#      21    -205.251076798401     -0.000000376321      0.00004188      0.00000925      0.00017402      0.00003975  ~
#   --------------------------------------------------------------------------------------------------------------- ~
#
# 	Writing optimization data to binary file.
# 	Final energy is   -205.2510767984008
# 	Final (previous) structure:
# 	Cartesian Geometry (in Angstrom)
# 	    N     1.2026667468  -0.8343434613   0.0000000000
# 	    C    -1.6564638513  -0.2713500609   0.0000000000
# 	    C    -0.6503121210   0.5978443752   0.0000000000
# 	    O     0.7354147624   0.3822395144   0.0000000000
# 	    H    -0.9154526788   1.6387299502   0.0000000000
# 	Saving final (previous) structure.
# 	Cleaning optimization helper files.
# -205.25107679840085
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Final optimized geometry and variables:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N            1.202666751483    -0.834343464544     0.000000000000
#     C           -1.656463857768    -0.271350061996     0.000000000000
#     C           -0.650312123551     0.597844377565     0.000000000000
#     O            0.735414765323     0.382239515889     0.000000000000
#     H           -0.915452682415     1.638729956691     0.000000000000
#
# 	Removing binary optimization data file.
# 	Cleaning optimization helper files.
