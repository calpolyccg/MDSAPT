# %% [markdown]
# #Optimizer Methods Testing
#
# This is notebook for testing the workflow of the optimizer object in MDSAPT. Optimizer was developed to solve the issue of residues having an unbalanced spin when drawn directly from protein backbone. It does this over a few steps addressing the different issues.

# %%
import os

import numpy as np

import MDAnalysis as mda

from pdbfixer import PDBFixer

from simtk.openmm.app import PDBFile

import nglview as nv

from mdsapt.reader import InputReader

# %%
In = InputReader(os.path.join(os.getcwd(), 'mdsapt', 'tests', 'testing_resources', 'test_input.yaml'))

unv = mda.Universe(In.top_path, In.trj_path)
# Out:
# 'pH' Error in trajectory settings

# %% [markdown]
# ##1: Loading the Residue
#
# In this case ARG is the residue. Both the amino and carboxyl side of the residue are missing protons.

# %%
# Selection prior to fixing

res = unv.select_atoms('resid 2')

nv.show_mdanalysis(res)
# Out:
# NGLWidget(max_frame=97)

# %% [markdown]
# ##2: Replacing missing Amino Protons
# The file is loaded into PDBFixer from opennm and amino protons are reattached.

# %%
# Fixing file

res.write('resid.pdb', file_format='PDB')
fixer = PDBFixer(filename='resid.pdb')
fixer.findMissingResidues()
fixer.findMissingAtoms()
fixer.addMissingHydrogens(7)
PDBFile.writeFile(fixer.topology, fixer.positions, open('resid_fixed.pdb', 'w'))


res_fixed = mda.Universe('resid_fixed.pdb')
resid: mda.AtomGroup = res_fixed.select_atoms("resname *")
resid.guess_bonds()
nv.show_mdanalysis(resid)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'tempfactors' Using default value of '0.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1124: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# NGLWidget()

# %% [markdown]
# ##3: Removing Proton on Alpha Carbon
#
# PDBFixer adds a redundant proton on the alpha carbon. This must be removed to proceed.

# %%
bkbone_fixed = mda.Universe('resid_fixed.pdb') # Load PDBRepair segid
bkbone_resid = bkbone_fixed.select_atoms("backbone") # Load backbone
ha = bkbone_fixed.select_atoms('name HA') # Remove proton on Alpha carbon
bkbone_resid = bkbone_resid - ha # Remove proton on Alpha carbon
nv.show_mdanalysis(bkbone_resid)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# NGLWidget()

# %% [markdown]
# ##4: Adding New Proton
#
# The carbon on the carboxyl end of the residue only has three bonds when removed from the backbone. Rather than adding a hydroxyl group, a proton is added to the end as a 4th bond.

# %%
bkbone_fixed = mda.Universe('bkboneid_fixed.pdb') # Load PDBRepair segid
bkbone_resid = bkbone_fixed.select_atoms("backbone") # Load backbone
ha = bkbone_fixed.select_atoms('name HA') # Remove proton on Alpha carbon
bkbone_resid = bkbone_resid - ha # Remove proton on Alpha carbon
carbon = bkbone_resid.select_atoms('name C') 
pos = carbon.atoms[0].position # Get postion of end carbon
h = mda.Universe.empty(n_atoms=bkbone_resid.n_atoms + 1, trajectory=True)
h.add_TopologyAttr("masses", [x for x in bkbone_resid.masses] + [1])
h.add_TopologyAttr("name", [x for x in bkbone_resid.names] + ['H'])
bkbone_pos = bkbone_resid.positions
h.atoms.positions = np.row_stack((bkbone_pos, np.array([pos[0] - np.cos(np.pi/6), pos[1] - np.sin(np.pi/6), pos[2]])))
nv.show_mdanalysis(h)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:433: UserWarning: Residues specified but no atom_resindex given.  All atoms will be placed in first Residue.
#   warnings.warn(
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:439: UserWarning: Segments specified but no segment_resindex given.  All residues will be placed in first Segment
#   warnings.warn(
# NGLWidget()

# %% [markdown]
# ##5 Optimizing New Bond
#
# Psi4 is employed to optimize the length of the newly added C-H bond.

# %%
import psi4
coords: str = ''
opt_settings: dict = {'reference': 'rhf',
                      'freeze_list': ''}

# Getting coords and settings
for n in range(len(h.atoms)):
    atom = h.atoms[n]
    coords += f"\n{atom.name} {atom.position[0]} {atom.position[1]} {atom.position[1]}"
    if not atom.name == 'H':
        opt_settings['freeze_list'] += f"\n{n + 1} xyz"
print(opt_settings['freeze_list'])
print(coords)
mol = psi4.geometry(coords)
# Out:
# 1 xyz
# 2 xyz
# 3 xyz
# 4 xyz
#
# N 11.840999603271484 6.642000198364258 6.642000198364258
# CA 11.414999961853027 5.434000015258789 5.434000015258789
# C 10.770999908447266 5.855000019073486 5.855000019073486
# O 11.35200023651123 6.664000034332275 6.664000034332275
# H 9.904974937438965 5.355000019073486 5.355000019073486

# %%
psi4.set_memory('8GB')
psi4.optimize('scf/cc-pvdz', molecule=mol)
# Out:
#   Memory set to   7.451 GiB by Python driver.
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 16:12:05 2021
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry CA         line   778 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4 entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5 entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.999940056626    -0.477732736780     0.000000000000    14.003074004430
#          CA          -0.708430185671    -0.051733095362     0.000000000000    39.962590863000
#          C           -0.113046270517     0.592266958044     0.000000000000    12.000000000000
#          O            1.031052523022     0.011266629980     0.000000000000    15.994914619570
#          H           -0.820153051704     1.458291929052     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      1.98034  B =      0.31784  C =      0.27389 [cm^-1]
#   Rotational constants: A =  59369.12240  B =   9528.70421  C =   8210.86578 [MHz]
#   Nuclear repulsion =  270.818008796671734
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 42
#   Nalpha       = 21
#   Nbeta        = 21
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 32
#     Number of basis functions: 74
#     Number of Cartesian functions: 79
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1 entry N          line   171 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2 entry CA         line  1250 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/def2-universal-jkfit.gbs
#     atoms 3 entry C          line   121 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 4 entry O          line   221 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 5 entry H          line    51 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1 entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2 entry CA         line   778 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4 entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5 entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.973.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.018 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT + DEF2-UNIVERSAL-JKFIT
#     Number of shells: 125
#     Number of basis functions: 393
#     Number of Cartesian functions: 471
#     Spherical Harmonics?: true
#     Max angular momentum: 4
#
#   Minimum eigenvalue in the overlap matrix is 9.4310277947E-04.
#   Reciprocal condition number of the overlap matrix is 1.7726810843E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        53      53      17      17      17       0
#      A"        21      21       4       4       4       0
#    -------------------------------------------------------
#     Total      74      74      21      21      21       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -841.56465183387081   -8.41565e+02   1.66220e-01
#    @DF-RHF iter   1:  -834.09076567822751    7.47389e+00   2.20249e-02 DIIS
#    @DF-RHF iter   2:  -834.13178061323299   -4.10149e-02   2.00065e-02 DIIS
#    @DF-RHF iter   3:  -834.85302862463152   -7.21248e-01   3.76094e-03 DIIS
#    @DF-RHF iter   4:  -834.89462134956671   -4.15927e-02   1.23734e-03 DIIS
#    @DF-RHF iter   5:  -834.90115235810686   -6.53101e-03   5.55684e-04 DIIS
#    @DF-RHF iter   6:  -834.90488284016203   -3.73048e-03   3.18620e-04 DIIS
#    @DF-RHF iter   7:  -834.90641556196783   -1.53272e-03   1.47064e-04 DIIS
#    @DF-RHF iter   8:  -834.90674216288960   -3.26601e-04   7.44290e-05 DIIS
#    @DF-RHF iter   9:  -834.90688859246995   -1.46430e-04   3.41065e-05 DIIS
#    @DF-RHF iter  10:  -834.90691842832416   -2.98359e-05   1.62401e-05 DIIS
#    @DF-RHF iter  11:  -834.90692456175941   -6.13344e-06   6.95001e-06 DIIS
#    @DF-RHF iter  12:  -834.90692577100515   -1.20925e-06   3.19137e-06 DIIS
#    @DF-RHF iter  13:  -834.90692608727170   -3.16267e-07   1.52854e-06 DIIS
#    @DF-RHF iter  14:  -834.90692615467617   -6.74045e-08   5.10098e-07 DIIS
#    @DF-RHF iter  15:  -834.90692616176716   -7.09099e-09   2.30649e-07 DIIS
#    @DF-RHF iter  16:  -834.90692616309775   -1.33059e-09   7.63541e-08 DIIS
#    @DF-RHF iter  17:  -834.90692616322110   -1.23350e-10   3.43929e-08 DIIS
#    @DF-RHF iter  18:  -834.90692616324793   -2.68301e-11   1.87742e-08 DIIS
#    @DF-RHF iter  19:  -834.90692616325634   -8.41283e-12   5.63113e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap  -149.283354     2Ap   -21.520287     3Ap   -16.734062
#        4Ap   -16.484989     5Ap   -13.559276     6Ap   -13.529350
#        1App  -13.528396     7Ap   -11.445233     8Ap    -2.458570
#        9Ap    -2.164999    10Ap    -1.799721     2App   -1.722549
#       11Ap    -1.460143     3App   -1.401283    12Ap    -1.372917
#       13Ap    -1.171984    14Ap    -0.903708    15Ap    -0.660215
#        4App   -0.471654    16Ap    -0.367728    17Ap    -0.137497
#
#     Virtual:
#
#       18Ap     0.026525     5App    0.032088    19Ap     0.045068
#       20Ap     0.081942     6App    0.126904    21Ap     0.136708
#       22Ap     0.155662     7App    0.160661    23Ap     0.190120
#       24Ap     0.215428     8App    0.219350    25Ap     0.242522
#        9App    0.300435    26Ap     0.325022    27Ap     0.341525
#       10App    0.376471    28Ap     0.406345    29Ap     0.482468
#       11App    0.544161    30Ap     0.546832    31Ap     0.589798
#       32Ap     0.645854    12App    0.705882    33Ap     0.838959
#       34Ap     1.004826    13App    1.018425    35Ap     1.043988
#       36Ap     1.113862    37Ap     1.212805    14App    1.280602
#       15App    1.324384    38Ap     1.380463    39Ap     1.421743
#       16App    1.685762    40Ap     1.708031    41Ap     1.848144
#       42Ap     1.937105    17App    2.063733    43Ap     2.112327
#       18App    2.140870    44Ap     2.268505    45Ap     2.453902
#       46Ap     2.829899    47Ap     2.875610    19App    2.913846
#       48Ap     3.246025    20App    3.427853    49Ap     3.598945
#       50Ap     4.010549    51Ap     4.551378    21App    4.912265
#       52Ap     5.302173    53Ap    13.217011
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [    17,    4 ]
#
#   @DF-RHF Final Energy:  -834.90692616325634
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =            270.8180087966717338
#     One-Electron Energy =               -1667.0940405468329573
#     Two-Electron Energy =                 561.3691055869047659
#     Total Energy =                       -834.9069261632563439
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -0.7919      Y:     1.3667      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     2.2803      Y:    -1.9703      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:     1.4885      Y:    -0.6036      Z:     0.0000     Total:     1.6062
#
#   Dipole Moment: [D]
#      X:     3.7833      Y:    -1.5342      Z:     0.0000     Total:     4.0826
#
#
# *** tstop() called on Alias-MBP at Mon Nov 22 16:12:06 2021
# Module time:
# 	user time   =       1.17 seconds =       0.02 minutes
# 	system time =       0.09 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      44.77 seconds =       0.75 minutes
# 	system time =       3.82 seconds =       0.06 minutes
# 	total time  =       1035 seconds =      17.25 minutes
# Optimizer: Optimization failed!
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 16:12:06 2021
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.999940056626    -0.477732736780     0.000000000000    14.003074004430
#          CA          -0.708430185671    -0.051733095362     0.000000000000    39.962590863000
#          C           -0.113046270517     0.592266958044     0.00000000
# 0000    12.000000000000
#          O            1.031052523022     0.011266629980     0.000000000000    15.994914619570
#          H           -0.820153051704     1.458291929052     0.000000000000     1.007825032230
#
#   Nuclear repulsion =  270.818008796671734
#
#   ==> Basis Set <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 32
#     Number of basis functions: 74
#     Number of Cartesian functions: 79
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT + DEF2-UNIVERSAL-JKFIT
#     Number of shells: 125
#     Number of basis functions: 393
#     Number of Cartesian functions: 471
#     Spherical Harmonics?: true
#     Max angular momentum: 4
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        1.337333256324    24.736384825240     0.000000000000
#        2        3.791436446415     3.976606824624     0.000000000000
#        3       -2.893417596670    -4.255336175942     0.000000000000
#        4       -2.262145152650   -24.304672498324     0.000000000000
#        5        0.026793046672    -0.152982975600     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Nov 22 16:12:07 2021
# Module time:
# 	user time   =       1.21 seconds =       0.02 minutes
# 	system time =       0.06 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      45.99 seconds =       0.77 minutes
# 	system time =       3.88 seconds =       0.06 minutes
# 	total time  =       1036 seconds =      17.27 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 N           1.8896128489       -0.9027840337        0.0000000000
# 	 CA         -1.3387390299       -0.0977613819        0.0000000000
# 	 C          -0.2136264908        1.1192223439        0.0000000000
# 	 O           1.9484068895        0.0212908450        0.0000000000
# 	 H          -1.5498646487        2.7557723569        0.0000000000
# 	             1.3373332563       24.7363848252        0.0000000000
# 	             3.7914364464        3.9766068246        0.0000000000
# 	            -2.8934175967       -4.2553361759        0.0000000000
# 	            -2.2621451527      -24.3046724983        0.0000000000
# 	             0.0267930467       -0.1529829756        0.0000000000
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.327209	       1.760683
# 	 R(1,3)           =         2.917555	       1.543903
# 	 R(1,4)           =         0.925943	       0.489988
# 	 R(2,3)           =         1.657386	       0.877051
# 	 R(2,4)           =         3.289301	       1.740623
# 	 R(2,5)           =         2.861333	       1.514152
# 	 R(3,4)           =         2.424839	       1.283169
# 	 R(3,5)           =         2.112777	       1.118034
# 	 B(1,2,3)         =         1.068981	      61.248075
# 	 B(1,2,4)         =         0.280578	      16.075943
# 	 B(1,2,5)         =         1.889026	     108.233197
# 	 B(1,3,2)         =         1.551279	      88.881768
# 	 B(1,3,4)         =         0.295822	      16.949363
# 	 B(1,4,2)         =         1.471056	      84.285273
# 	 B(1,4,3)         =         1.977144	     113.282011
# 	 B(2,1,3)         =         0.521333	      29.870157
# 	 B(2,1,4)         =         1.389959	      79.638783
# 	 B(2,3,4)         =         1.847102	     105.831131
# 	 B(2,3,5)         =         1.710681	      98.014801
# 	 B(2,4,3)         =         0.506089	      28.996737
# 	 B(2,5,3)         =         0.610867	      35.000077
# 	 B(3,1,4)         =         0.868626	      49.768627
# 	 B(3,2,4)         =         0.788402	      45.172132
# 	 B(3,2,5)         =         0.820045	      46.985122
# 	 B(4,2,5)         =         1.608448	      92.157254
# 	 B(4,3,5)         =         2.725403	     156.154068
# 	 L(1,3,5)         =         3.021225	     173.103431
# 	 l(1,3,5)         =         3.141593	     180.000000
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,2,5,3)       =         0.000000	       0.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,2,5)       =         3.141593	     180.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,2,5)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(2,5,3,4)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,1,2,5)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(3,4,2,5)       =         0.000000	       0.000000
# 	 D(3,5,2,4)       =         0.000000	       0.000000
# 	 D(4,1,2,5)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
# 	 D(4,3,2,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -834.9069261633
#
# 	Energy change for the previous step:
# 		Projected    :        -0.0126450667
# 		Actual       :         9.3139255728
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Change in internal coordinate of 3.22e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 15.
# 	Change in internal coordinate of 2.84e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 14.
# 	Change in internal coordinate of 2.68e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 13.
# 	Change in internal coordinate of 2.50e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 12.
# 	Change in internal coordinate of 2.29e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 11.
# 	Change in internal coordinate of 2.06e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 10.
# 	Change in internal coordinate of 1.77e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 9.
# 	Change in internal coordinate of 1.50e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 8.
# 	Change in internal coordinate of 1.32e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 7.
# 	Change in internal coordinate of 1.25e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 6.
# 	Change in internal coordinate of 1.20e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 5.
# 	Change in internal coordinate of 1.16e+00 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 4.
# 	Change in internal coordinate of 7.80e-01 exceeds limit of 5.00e-01.
# 	 Skipping Hessian update for step 3.
# 	Denominators (dg)(dq) or (dq)(dq) are very small.
# 	 Skipping Hessian update for step 1.
# 	Steps to be used in Hessian update: 2
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
#
# 	Determining step-restricting scale parameter for RS-RFO.
# 	Maximum step size allowed    1.00000
#
# 	 Iter      |step|        alpha        rfo_root
# 	------------------------------------------------
# 	    0     1.02485       1.00000           1
# 	    1     1.00086       1.04709           1
# 	    2     1.00000       1.04885           1
# 	------------------------------------------------
# 	Norm of target step-size    1.00000
# 	Projected energy change by RFO approximation:        -9.7806734046
#
# 	Back-transformation to cartesian coordinates...
# 	The INTCO_EXCEPTion handler:
# 	TORS::compute_val: unable to compute torsion value
# 	Dynamic level is 0.
# 	exc.g_really_quit() is 0.
#
#   **** Optimization has failed! (in 16 steps) ****
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
# 	Removing binary optimization data file.
# 	Cleaning optimization helper files.
#
# PsiException: Could not converge geometry optimization in 0 iterations.
# TORS::compute_val: unable to compute torsion value
# ---------------------------------------------------------------------------
# OptimizationConvergenceError              Traceback (most recent call last)
# /var/folders/tm/l9n3216d1nd4rx41smlqm5pc0000gn/T/ipykernel_973/1693155860.py in <module>
#       1 psi4.set_memory('8GB')
# ----> 2 psi4.optimize('scf/cc-pvdz', molecule=mol)
#
# ~/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/psi4/driver/driver.py in optimize(name, **kwargs)
#    1431             core.clean()
#    1432             optstash.restore()
# -> 1433             raise OptimizationConvergenceError("""geometry optimization""", n - 1, wfn)
#    1434             return thisenergy
#    1435
#
# OptimizationConvergenceError: Could not converge geometry optimization in 0 iterations.
