# %% [markdown]
# #Optimizer Methods Testing
#
# This is notebook for testing the workflow of the optimizer object in MDSAPT. Optimizer was developed to solve the issue of residues having an unbalanced spin when drawn directly from protein backbone. It does this over a few steps addressing the different issues.

# %%
import os

import numpy as np

import MDAnalysis as mda

from pdbfixer import PDBFixer

from simtk.openmm.app import PDBFile

import nglview as nv

from mdsapt.reader import InputReader
# Out:
# 2021-11-22 19:06:51,857 MDSAPT       INFO     MDSAPT 0.0.0+25.g42eb0b1.dirty starting
# 2021-11-22 19:06:51,861 MDSAPT       INFO     Copyright (c) 2021 Alia Lescoulie
# 2021-11-22 19:06:51,863 MDSAPT       INFO     Released under MIT Licence

# %%
In = InputReader(os.path.join(os.getcwd(), 'mdsapt', 'tests', 'testing_resources', 'test_input.yaml'))

unv = mda.Universe(In.top_path, In.trj_path)
# Out:
# 'pH' Error in trajectory settings

# %% [markdown]
# ##1. Loading the Residue
#
# In this case ARG is the residue. Both the amino and carboxyl side of the residue are missing protons.

# %%
# Selection prior to fixing

res = unv.select_atoms('resid 2')

nv.show_mdanalysis(res)
# Out:
# NGLWidget(max_frame=97)

# %% [markdown]
# ##2. Replacing missing Amino Protons
# The file is loaded into PDBFixer from opennm and amino protons are reattached.

# %%
res.write('resid.pdb', file_format='PDB') # Saving residue
fixer = PDBFixer(filename='resid.pdb')
fixer.findMissingResidues()
fixer.findMissingAtoms()
fixer.addMissingHydrogens(7) # Adding protons at pH value
PDBFile.writeFile(fixer.topology, fixer.positions, open('resid_fixed.pdb', 'w'))


res_fixed = mda.Universe('resid_fixed.pdb')
resid: mda.AtomGroup = res_fixed.select_atoms("resname *")
resid.guess_bonds()
nv.show_mdanalysis(resid)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:747: UserWarning: Unit cell dimensions not found. CRYST1 record set to unitary values.
#   warnings.warn("Unit cell dimensions not found. "
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'altLocs' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'icodes' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'chainIDs' Using default value of ''
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'occupancies' Using default value of '1.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'tempfactors' Using default value of '0.0'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'elements' Using default value of ' '
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1078: UserWarning: Found no information for attr: 'record_types' Using default value of 'ATOM'
#   warnings.warn("Found no information for attr: '{}'"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:1124: UserWarning: Found missing chainIDs. Corresponding atoms will use value of 'X'
#   warnings.warn("Found missing chainIDs."
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# NGLWidget()

# %% [markdown]
# ##3. Removing Proton on Alpha Carbon
#
# PDBFixer adds a redundant proton on the alpha carbon. This must be removed to proceed.

# %%
bkbone_fixed = mda.Universe('resid_fixed.pdb') # Load PDBRepair segid
bkbone_resid = bkbone_fixed.select_atoms("backbone") # Load backbone
ha = bkbone_fixed.select_atoms('name HA') # Remove proton on Alpha carbon
bkbone_resid = bkbone_resid - ha # Remove proton on Alpha carbon
nv.show_mdanalysis(bkbone_resid)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# NGLWidget()

# %% [markdown]
# ##4. Adding New Proton
#
# The carbon on the carboxyl end of the residue only has three bonds when removed from the backbone. Rather than adding a hydroxyl group, a proton is added to the end as a 4th bond.

# %%
bkbone_fixed = mda.Universe('bkboneid_fixed.pdb') # Load PDBRepair segid
bkbone_resid = bkbone_fixed.select_atoms("backbone") # Load backbone
ha = bkbone_fixed.select_atoms('name HA') # Remove proton on Alpha carbon
bkbone_resid = bkbone_resid - ha # Remove proton on Alpha carbon
carbon = bkbone_resid.select_atoms('name C') 
pos = carbon.atoms[0].position # Get postion of end carbon
h = mda.Universe.empty(n_atoms=bkbone_resid.n_atoms + 1, trajectory=True)
h.add_TopologyAttr("masses", [x for x in bkbone_resid.masses] + [1])
h.add_TopologyAttr("name", [x for x in bkbone_resid.names] + ['H'])
bkbone_pos = bkbone_resid.positions
h.atoms.positions = np.row_stack((bkbone_pos, np.array([pos[0] - np.cos(np.pi/6), pos[1] - np.sin(np.pi/6), pos[2]])))
nv.show_mdanalysis(h)
# Out:
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/coordinates/PDB.py:429: UserWarning: 1 A^3 CRYST1 record, this is usually a placeholder. Unit cell dimensions will be set to None.
#   warnings.warn("1 A^3 CRYST1 record,"
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:433: UserWarning: Residues specified but no atom_resindex given.  All atoms will be placed in first Residue.
#   warnings.warn(
# /Users/alia/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/MDAnalysis/core/universe.py:439: UserWarning: Segments specified but no segment_resindex given.  All residues will be placed in first Segment
#   warnings.warn(
# NGLWidget()

# %% [markdown]
# ##5. Optimizing New Bond
#
# Psi4 is employed to optimize the length of the newly added C-H bond.

# %%
import psi4
coords: str = ''
opt_settings: dict = {'reference': 'rhf',
                      'freeze_list': ''} # Psi4 settings

# Getting coords and settings
for n in range(len(h.atoms)):
    atom = h.atoms[n]
    coords += f"\n{atom.name[0]} {atom.position[0]} {atom.position[1]} {atom.position[1]}"
    if not atom.name == 'H':
        opt_settings['freeze_list'] += f"\n{n + 1} xyz" # Freezing bonds besides H
print(opt_settings['freeze_list'])
print(coords)
mol = psi4.geometry(coords)
# Out:
# 1 xyz
# 2 xyz
# 3 xyz
# 4 xyz
#
# N 11.840999603271484 6.642000198364258 6.642000198364258
# C 11.414999961853027 5.434000015258789 5.434000015258789
# C 10.770999908447266 5.855000019073486 5.855000019073486
# O 11.35200023651123 6.664000034332275 6.664000034332275
# H 9.904974937438965 5.355000019073486 5.355000019073486

# %%
psi4.set_memory('8GB')
psi4.optimize('scf/cc-pvdz', molecule=mol)
# Out:
#   Memory set to   7.451 GiB by Python driver.
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 19:06:54 2021
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5   entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.639804606931    -0.504031618363     0.000000000000    14.003074004430
#          C           -1.068565635366    -0.078031976944     0.000000000000    12.000000000000
#          C           -0.473181720212     0.565968076462     0.000000000000    12.000000000000
#          O            0.670917073327    -0.015032251602     0.000000000000    15.994914619570
#          H           -1.180288501399     1.431993047470     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      2.59485  B =      0.49915  C =      0.41862 [cm^-1]
#   Rotational constants: A =  77791.64732  B =  14964.09378  C =  12549.96717 [MHz]
#   Nuclear repulsion =  151.739053682449651
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 27
#     Number of basis functions: 61
#     Number of Cartesian functions: 65
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   171 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-3 entry C          line   121 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 4   entry O          line   221 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 5   entry H          line    51 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.010 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 105
#     Number of basis functions: 303
#     Number of Cartesian functions: 349
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 7.6211092334E-04.
#   Reciprocal condition number of the overlap matrix is 1.4033123042E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A'        44      44
#      A"        17      17
#    -------------------------
#     Total      61      61
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.639804606931    -0.504031618363     0.000000000000    14.003074004430
#          C           -1.068565635366    -0.078031976944     0.000000000000    12.000000000000
#          C           -0.473181720212     0.565968076462     0.000000000000    12.000000000000
#          O            0.670917073327    -0.015032251602     0.000000000000    15.994914619570
#          H           -1.180288501399     1.431993047470     0.000000000000     1.007825032230
#
#   Nuclear repulsion =  151.739053682449651
#
#   ==> Basis Set <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 27
#     Number of basis functions: 61
#     Number of Cartesian functions: 65
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 105
#     Number of basis functions: 303
#     Number of Cartesian functions: 349
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        1.259508010920    24.574158275485     0.000000000000
#        2        1.550733221229     1.489576714772     0.000000000000
#        3       -0.639613013135    -1.958928115437     0.000000000000
#        4       -2.134239596034   -24.117456285137     0.000000000000
#        5       -0.036388622979     0.012649410317     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Nov 22 19:06:54 2021
# Module time:
# 	user time   =       0.30 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       0.83 seconds =       0.01 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Internal coordinates to be generated automatically.
# 	Detected frag 1 with atoms:  1 2 3 4 5
# 	---Fragment 1 Bond Connectivity---
# 	 1 : 2 3 4
# 	 2 : 1 3 4
# 	 3 : 1 2 4 5
# 	 4 : 1 2 3
# 	 5 : 3
#
# 	---Fragment 1 Geometry and Gradient---
# 	 N           1.2090554809       -0.9524817173        0.0000000000
# 	 C          -2.0192963979       -0.1474590655        0.0000000000
# 	 C          -0.8941838588        1.0695246603        0.0000000000
# 	 O           1.2678495215       -0.0284068386        0.0000000000
# 	 H          -2.2304220167        2.7060746733        0.0000000000
# 	             1.2595080109       24.5741582755        0.0000000000
# 	             1.5507332212        1.4895767148        0.0000000000
# 	            -0.6396130131       -1.9589281154        0.0000000000
# 	            -2.1342395960      -24.1174562851        0.0000000000
# 	            -0.0363886230        0.0126494103        0.0000000000
#
# 	Previous optimization step data not found.  Starting new optimization.
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.327209	       1.760683
# 	 R(1,3)           =         2.917555	       1.543903
# 	 R(1,4)           =         0.925943	       0.489988
# 	 R(2,3)           =         1.657386	       0.877051
# 	 R(2,4)           =         3.289301	       1.740623
# 	 R(3,4)           =         2.424839	       1.283169
# 	 R(3,5)           =         2.112777	       1.118034
# 	 B(1,2,3)         =         1.068981	      61.248075
# 	 B(1,2,4)         =         0.280578	      16.075943
# 	 B(1,3,2)         =         1.551279	      88.881768
# 	 B(1,3,4)         =         0.295822	      16.949363
# 	 B(1,3,5)         =         3.021225	     173.103431
# 	 B(1,4,2)         =         1.471056	      84.285273
# 	 B(1,4,3)         =         1.977144	     113.282011
# 	 B(2,1,3)         =         0.521333	      29.870157
# 	 B(2,1,4)         =         1.389959	      79.638783
# 	 B(2,3,4)         =         1.847102	     105.831131
# 	 B(2,3,5)         =         1.710681	      98.014801
# 	 B(2,4,3)         =         0.506089	      28.996737
# 	 B(3,1,4)         =         0.868626	      49.768627
# 	 B(3,2,4)         =         0.788402	      45.172132
# 	 B(4,3,5)         =         2.725403	     156.154068
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,3,5)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,1,3,5)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -197.8739693454
#
# 	Generating empirical Hessian (Schlegel '84) for each fragment.
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
#
# 	Determining step-restricting scale parameter for RS-RFO.
# 	Maximum step size allowed    0.50000
#
# 	 Iter      |step|        alpha        rfo_root
# 	------------------------------------------------
# 	    0    14.08219       1.00000           1
# 	    1     7.18515       1.96932           1
# 	    2     3.73801       3.81950           1
# 	    3     2.01733       7.18965           1
# 	    4     1.16310      12.78087           1
# 	    5     0.74871      20.48603           1
# 	    6     0.56556      27.87994           1
# 	    7     0.50741      31.47212           1
# 	    8     0.50012      31.98810           1
# 	    9     0.50000      31.99659           1
# 	------------------------------------------------
# 	Norm of target step-size    0.50000
# 	Projected energy change by RFO approximation:        -7.7491357193
# 	Newly linear bends that need to be incorporated into the internal coordinates:
# 	    1    3    5
# 	The INTCO_EXCEPTion handler:
# 	New linear angles
# 	Dynamic level is 0.
# 	exc.g_really_quit() is 0.
# 	Restarting with new internal coordinates at same level.	Removing binary optimization data file.
#
#     Structure for next step:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N            0.639804606931    -0.504031618363     0.000000000000
#     C           -1.068565635366    -0.078031976944     0.000000000000
#     C           -0.473181720212     0.565968076462     0.000000000000
#     O            0.670917073327    -0.015032251602     0.000000000000
#     H           -1.180288501399     1.431993047470     0.000000000000
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 19:06:55 2021
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5   entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.639804606931    -0.504031618363     0.000000000000    14.003074004430
#          C           -1.068565635366    -0.078031976944     0.000000000000    12.000000000000
#          C           -0.473181720212     0.565968076462     0.000000000000    12.000000000000
#          O            0.670917073327    -0.015032251602     0.000000000000    15.994914619570
#          H           -1.180288501399     1.431993047470     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      2.59485  B =      0.49915  C =      0.41862 [cm^-1]
#   Rotational constants: A =  77791.64732  B =  14964.09378  C =  12549.96717 [MHz]
#   Nuclear repulsion =  151.739053682449651
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 27
#     Number of basis functions: 61
#     Number of Cartesian functions: 65
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   171 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-3 entry C          line   121 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 4   entry O          line   221 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 5   entry H          line    51 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
# New linear angles
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5   entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.1438.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.010 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 105
#     Number of basis functions: 303
#     Number of Cartesian functions: 349
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 7.6211092334E-04.
#   Reciprocal condition number of the overlap matrix is 1.4033123042E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        44      44      12      12      12       0
#      A"        17      17       2       2       2       0
#    -------------------------------------------------------
#     Total      61      61      14      14      14       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -197.87396934511864   -1.97874e+02   1.24697e-09
#    @DF-RHF iter   1:  -197.87396934511870   -5.68434e-14   5.06048e-10 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap   
minutes
# 	system time =       0.11 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Internal coordinates to be generated automatically.
# 	Detected frag 1 with atoms:  1 2 3 4 5
# 	---Fragment 1 Bond Connectivity---
# 	 1 : 2 3 4
# 	 2 : 1 3 4
# 	 3 : 1 2 4 5
# 	 4 : 1 2 3
# 	 5 : 3
#
# 	Exception forcing addition of linear bend (1,3,5)
# 	Exception forcing addition of linear bend complement (1,3,5)
# 	---Fragment 1 Geometry and Gradient---
# 	 N           1.2090554809       -0.9524817173        0.0000000000
# 	 C          -2.0192963979       -0.1474590655        0.0000000000
# 	 C          -0.8941838588        1.0695246603        0.0000000000
# 	 O           1.2678495215       -0.0284068386        0.0000000000
# 	 H          -2.2304220167        2.7060746733        0.0000000000
# 	             1.2595079723       24.5741579953        0.0000000000
# 	             1.5507332386        1.4895768187        0.0000000000
# 	            -0.6396131523       -1.9589281473        0.0000000000
# 	            -2.1342394638      -24.1174560461        0.0000000000
# 	            -0.0363885949        0.0126493794        0.0000000000
#
# 	Previous optimization step data not found.  Starting new optimization.
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         3.327209	       1.760683
# 	 R(1,3)           =         2.917555	       1.543903
# 	 R(1,4)           =         0.925943	       0.489988
# 	 R(2,3)           =         1.657386	       0.877051
# 	 R(2,4)           =         3.289301	       1.740623
# 	 R(3,4)           =         2.424839	       1.283169
# 	 R(3,5)           =         2.112777	       1.118034
# 	 B(1,2,3)         =         1.068981	      61.248075
# 	 B(1,2,4)         =         0.280578	      16.075943
# 	 B(1,3,2)         =         1.551279	      88.881768
# 	 B(1,3,4)         =         0.295822	      16.949363
# 	 B(1,4,2)         =         1.471056	      84.285273
# 	 B(1,4,3)         =         1.977144	     113.282011
# 	 B(2,1,3)         =         0.521333	      29.870157
# 	 B(2,1,4)         =         1.389959	      79.638783
# 	 B(2,3,4)         =         1.847102	     105.831131
# 	 B(2,3,5)         =         1.710681	      98.014801
# 	 B(2,4,3)         =         0.506089	      28.996737
# 	 B(3,1,4)         =         0.868626	      49.768627
# 	 B(3,2,4)         =         0.788402	      45.172132
# 	 B(4,3,5)         =         2.725403	     156.154068
# 	 L(1,3,5)         =         3.021225	     173.103431
# 	 l(1,3,5)         =         3.141593	     180.000000
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -197.8739693451
#
# 	Generating empirical Hessian (Schlegel '84) for each fragment.
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
#
# 	Determining step-restricting scale parameter for RS-RFO.
# 	Maximum step size allowed    0.50000
#
# 	 Iter      |step|        alpha        rfo_root
# 	------------------------------------------------
# 	    0    14.08219       1.00000           1
# 	    1     7.18515       1.96932           1
# 	    2     3.73801       3.81950           1
# 	    3     2.01733       7.18965           1
# 	    4     1.16310      12.78087           1
# 	    5     0.74871      20.48603           1
# 	    6     0.56556      27.87994           1
# 	    7     0.50741      31.47212           1
# 	    8     0.50012      31.98810           1
# 	    9     0.50000      31.99659           1
# 	------------------------------------------------
# 	Norm of target step-size    0.50000
# 	Projected energy change by RFO approximation:        -7.7562773797
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.760683     8.507644     0.008992     1.769675
# 	    2 R(1,3)          =      1.543903    40.494921     0.064727     1.608630
# 	    3 R(1,4)          =      0.489988   126.631064     0.209762     0.699751
# 	    4 R(2,3)          =      0.877051    11.506992     0.004815     0.881865
# 	    5 R(2,4)          =      1.740623     5.895817     0.002740     1.743363
# 	    6 R(3,4)          =      1.283169   -26.991883    -0.045688     1.237481
# 	    7 R(3,5)          =      1.118034    -0.270332    -0.000056     1.117978
# 	    8 B(1,2,3)        =     61.248075     0.183333     3.698112    64.946188
# 	    9 B(1,2,4)        =     16.075943     0.351363     6.887047    22.962991
# 	   10 B(1,3,2)        =     88.881768    -0.204307    -3.605131    85.276638
# 	   11 B(1,3,4)        =     16.949363     0.372389     7.321573    24.270936
# 	   12 B(1,4,2)        =     84.285273    -0.202115    -3.655013    80.630260
# 	   13 B(1,4,3)        =    113.282011    -0.202166    -4.182521   109.099490
# 	   14 B(2,1,3)        =     29.870157     0.020974    -0.092982    29.777175
# 	   15 B(2,1,4)        =     79.638783    -0.149248    -3.232034    76.406749
# 	   16 B(2,3,4)        =    105.831131     0.168082     3.716443   109.547573
# 	   17 B(2,3,5)        =     98.014801     0.013157    -0.034478    97.980323
# 	   18 B(2,4,3)        =     28.996737    -0.000051    -0.527508    28.469230
# 	   19 B(3,1,4)        =     49.768627    -0.170222    -3.139052    46.629574
# 	   20 B(3,2,4)        =     45.172132    -0.168031    -3.188935    41.983197
# 	   21 B(4,3,5)        =    156.154068    -0.181239    -3.681964   152.472104
# 	   22 L(1,3,5)        =    173.103431     0.191150     3.639609   176.743040
# 	   23 l(1,3,5)        =    180.000000     0.000000     0.000000   180.000000
# 	   24 D(1,2,3,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   25 D(1,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   26 D(1,2,4,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   27 D(1,3,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   28 D(1,3,4,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   29 D(1,4,2,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   30 D(1,4,3,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   31 D(1,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   32 D(2,1,3,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   33 D(2,1,4,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   34 D(2,3,1,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   35 D(2,4,1,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   36 D(2,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   37 D(3,1,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   38 D(3,2,1,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   39 D(4,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   --------------------------------------------------------------------------------------------- ~
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp    ~
#   --------------------------------------------------------------------------------------------- ~
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o  ~
#   --------------------------------------------------------------------------------------------- ~
#       1    -197.87396935   -1.98e+02      1.54e+01      3.11e+00 o    3.96e-01      8.01e-02 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    N     0.6273339493  -0.6082422907   0.0000000000
# 	    C    -1.0621632324  -0.0816036055   0.0000000000
# 	    C    -0.4678971790   0.5699594520   0.0000000000
# 	    O     0.6727305412   0.0900341491   0.0000000000
# 	    H    -1.1813182503   1.4307175666   0.0000000000
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N            0.627450589515    -0.612332948946     0.000000000000
#     C           -1.062046598837    -0.085694261696     0.000000000000
#     C           -0.467780543073     0.565868798334     0.000000000000
#     O            0.672847181606     0.085943493578     0.000000000000
#     H           -1.181201617248     1.426626916314     0.000000000000
#
#
# Scratch directory: /tmp/
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 19:06:55 2021
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5   entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,   7629 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.627450589515    -0.612332948946     0.000000000000    14.003074004430
#          C           -1.062046598837    -0.085694261696     0.000000000000    12.000000000000
#          C           -0.467780543073     0.565868798334     0.000000000000    12.000000000000
#          O            0.672847181606     0.085943493578     0.000000000000    15.994914619570
#          H           -1.181201617248     1.426626916314     0.000000000000     1.007825032230
#
#   Running in cs symmetry.
#
#   Rotational constants: A =      2.03775  B =      0.50473  C =      0.40453 [cm^-1]
#   Rotational constants: A =  61090.26348  B =  15131.44534  C =  12127.56834 [MHz]
#   Nuclear repulsion =  133.565209049283027
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 28
#   Nalpha       = 14
#   Nbeta        = 14
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-08
#   Density threshold  = 1.00e-08
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 27
#     Number of basis functions: 61
#     Number of Cartesian functions: 65
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1   entry N          line   171 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 2-3 entry C          line   121 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 4   entry O          line   221 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#     atoms 5   entry H          line    51 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1   entry N          line   168 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 2-3 entry C          line   138 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 4   entry O          line   198 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#     atoms 5   entry H          line    22 file /Users/alia/opt/anaconda3/envs/MDSAPT/share/psi4/basis/cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/stdout.default.1438.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.010 GiB; user supplied 5.588 GiB. Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:              5722
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 105
#     Number of basis functions: 303
#     Number of Cartesian functions: 349
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 7.6837787166E-04.
#   Reciprocal condition number of the overlap matrix is 1.4321609145E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A'        44      44      12      12      12       0
#      A"        17      17       2       2       2       0
#    -------------------------------------------------------
#     Total      61      61      14      14      14       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -204.91644286692647   -2.04916e+02   8.05559e-02
#    @DF-RHF iter   1:  -202.68943699937756    2.22701e+00   1.75527e-02 DIIS
#    @DF-RHF iter   2:  -202.86522290471947   -1.75786e-01   1.09063e-02 DIIS
#    @DF-RHF iter   3:  -202.95922885745657   -9.40060e-02   1.12297e-03 DIIS
#    @DF-RHF iter   4:  -202.96183627549260   -2.60742e-03   5.72014e-04 DIIS
#    @DF-RHF iter   5:  -202.96324369132023   -1.40742e-03   4.03178e-04 DIIS
#    @DF-RHF iter   6:  -202.96506224415123   -1.81855e-03   2.83635e-04 DIIS
#    @DF-RHF iter   7:  -202.96652152677254   -1.45928e-03   1.11141e-04 DIIS
#    @DF-RHF iter   8:  -202.96671419211211   -1.92665e-04   3.29583e-05 DIIS
#    @DF-RHF iter   9:  -202.96672712267059   -1.29306e-05   1.35292e-05 DIIS
#    @DF-RHF iter  10:  -202.96672898140602   -1.85874e-06   6.59323e-06 DIIS
#    @DF-RHF iter  11:  -202.96672920018977   -2.18784e-07   2.02916e-06 DIIS
#    @DF-RHF iter  12:  -202.96672921627291   -1.60831e-08   6.53878e-07 DIIS
#    @DF-RHF iter  13:  -202.96672921749609   -1.22319e-09   2.13161e-07 DIIS
#    @DF-RHF iter  14:  -202.96672921758517   -8.90736e-11   7.60338e-08 DIIS
#    @DF-RHF iter  15:  -202.96672921761470   -2.95302e-11   1.55586e-08 DIIS
#    @DF-RHF iter  16:  -202.96672921761555   -8.52651e-13   6.96918e-09 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1Ap   
#
#     Final Occupation by Irrep:
#              Ap   App
#     DOCC [    12,    2 ]
#
#   @DF-RHF Final Energy:  -205.53815669622145
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             90.5275370766569552
#     One-Electron Energy =                -458.6285280242035469
#     Two-Electron Energy =                 162.5628342513251710
#     Total Energy =                       -205.5381566962214492
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#   Nuclear Dipole Moment: [e a0]
#      X:    -1.0637      Y:     1.5670      Z:     0.0000
#
#   Electronic Dipole Moment: [e a0]
#      X:     0.1708      Y:    -0.4707      Z:     0.0000
#
#   Dipole Moment: [e a0]
#      X:    -0.8928      Y:     1.0963      Z:     0.0000     Total:     1.4139
#
#   Dipole Moment: [D]
#      X:    -2.2694      Y:     2.7865      Z:     0.0000     Total:     3.5937
#
#
# *** tstop() called on Alias-MBP at Mon Nov 22 19:07:34 2021
# Module time:
# 	user time   =       0.44 seconds =       0.01 minutes
# 	system time =       0.03 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      37.09 seconds =       0.62 minutes
# 	system time =       2.20 seconds =       0.04 minutes
# 	total time  =         40 seconds =       0.67 minutes
#
# *** tstart() called on Alias-MBP
# *** at Mon Nov 22 19:07:34 2021
#
#
#          ------------------------------------------------------------
#                                    SCF GRAD
#                           Rob Parrish, Justin Turney,
#                        Andy Simmonett, and Alex Sokolov
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          N            0.068096667192    -1.456099077603     0.000000000000    14.003074004430
#          C           -0.833964713164    -0.727465052614     0.000000000000    12.000000000000
#          C           -0.290041149863     0.882294220647     0.000000000000    12.000000000000
#          O            0.855410824359     1.053917837312     0.000000000000    15.994914619570
#          H           -1.138804234260     1.661585342357     0.000000000000     1.007825032230
#
#   Nuclear repulsion =   90.527537076656955
#
#   ==> Basis Set <==
#
#   Basis Set: CC-PVDZ
#     Blend: CC-PVDZ
#     Number of shells: 27
#     Number of basis functions: 61
#     Number of Cartesian functions: 65
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> DFJKGrad: Density-Fitted SCF Gradients <==
#
#     Gradient:                    1
#     J tasked:                  Yes
#     K tasked:                  Yes
#     wK tasked:                  No
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [MiB]:             5722
#     Schwarz Cutoff:          1E-12
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (CC-PVDZ AUX)
#     Blend: CC-PVDZ-JKFIT
#     Number of shells: 105
#     Number of basis functions: 303
#     Number of Cartesian functions: 349
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.036423670383     0.022018474573     0.000000000000
#        2       -0.061831923169    -0.041745342291     0.000000000000
#        3        0.042159193437     0.007274547119     0.000000000000
#        4        0.011414551464    -0.012862863495     0.000000000000
#        5       -0.028165492113     0.025315184094     0.000000000000
#
#
# *** tstop() called on Alias-MBP at Mon Nov 22 19:07:34 2021
# Module time:
# 	user time   =       0.30 seconds =       0.00 minutes
# 	system time =       0.01 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =      37.39 seconds =       0.62 minutes
# 	system time =       2.21 seconds =       0.04 minutes
# 	total time  =         40 seconds =       0.67 minutes
#
# 			-----------------------------------------
# 			 OPTKING 2.0: for geometry optimizations
# 			  - R.A. King,  Bethel University
# 			-----------------------------------------
#
# 	Previous internal coordinate definitions found.
# 	---Fragment 1 Geometry and Gradient---
# 	 N           0.1286840510       -2.7516284682        0.0000000000
# 	 C          -1.5759649062       -1.3747097153        0.0000000000
# 	 C          -0.5480983384        1.6672944391        0.0000000000
# 	 O           1.6164921828        1.9916160713        0.0000000000
# 	 H          -2.1520281133        3.1399412311        0.0000000000
# 	             0.0364236704        0.0220184746        0.0000000000
# 	            -0.0618319232       -0.0417453423        0.0000000000
# 	             0.0421591934        0.0072745471        0.0000000000
# 	             0.0114145515       -0.0128628635        0.0000000000
# 	            -0.0281654921        0.0253151841        0.0000000000
#
# 	---Fragment 1 Intrafragment Coordinates---
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.191286	       1.159578
# 	 R(1,3)           =         4.470449	       2.365660
# 	 R(1,4)           =         4.971111	       2.630598
# 	 R(2,3)           =         3.210965	       1.699170
# 	 R(2,4)           =         4.639389	       2.455059
# 	 R(3,4)           =         2.188752	       1.158238
# 	 R(3,5)           =         2.177448	       1.152256
# 	 B(1,2,3)         =         1.924394	     110.259651
# 	 B(1,2,4)         =         1.491346	      85.447826
# 	 B(1,3,2)         =         0.477822	      27.377163
# 	 B(1,3,4)         =         1.567546	      89.813764
# 	 B(1,4,2)         =         0.454946	      26.066468
# 	 B(1,4,3)         =         1.118123	      64.063717
# 	 B(2,1,3)         =         0.739377	      42.363187
# 	 B(2,1,4)         =         1.195301	      68.485706
# 	 B(2,3,4)         =         2.045368	     117.190927
# 	 B(2,3,5)         =         1.987702	     113.886909
# 	 B(2,4,3)         =         0.663177	      37.997249
# 	 B(3,1,4)         =         0.455924	      26.122519
# 	 B(3,2,4)         =         0.433048	      24.811824
# 	 B(4,3,5)         =         2.250116	     128.922164
# 	 L(1,3,5)         =         2.465523	     141.264072
# 	 l(1,3,5)         =         3.141593	     180.000000
# 	 D(1,2,3,4)       =         0.000000	       0.000000
# 	 D(1,2,3,5)       =         3.141593	     180.000000
# 	 D(1,2,4,3)       =         3.141593	     180.000000
# 	 D(1,3,2,4)       =         0.000000	       0.000000
# 	 D(1,3,4,2)       =         0.000000	       0.000000
# 	 D(1,4,2,3)       =         3.141593	     180.000000
# 	 D(1,4,3,2)       =         0.000000	       0.000000
# 	 D(1,4,3,5)       =         3.141593	     180.000000
# 	 D(2,1,3,4)       =         3.141593	     180.000000
# 	 D(2,1,4,3)       =         0.000000	       0.000000
# 	 D(2,3,1,4)       =         3.141593	     180.000000
# 	 D(2,4,1,3)       =         0.000000	       0.000000
# 	 D(2,4,3,5)       =         3.141593	     180.000000
# 	 D(3,1,2,4)       =         0.000000	       0.000000
# 	 D(3,2,1,4)       =         0.000000	       0.000000
# 	 D(4,2,3,5)       =         3.141593	     180.000000
#
# 	Current energy   :      -205.5381566962
#
# 	Energy change for the previous step:
# 		Projected    :        -0.0130591002
# 		Actual       :        -0.0132016712
#
# 	Performing BFGS update.
# 	Previous computed or guess Hessian on step 1.
# 	Steps to be used in Hessian update: 48 47
# 	Taking RFO optimization step.
# 	Going to follow RFO solution 1.
# 	Using RFO vector 1.
# 	Norm of target step-size    0.78559
# 	Projected energy change by RFO approximation:        -0.0222749492
#
# 	Back-transformation to cartesian coordinates...
# 	Successfully converged to displaced geometry.
#
# 	--- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	 ---------------------------------------------------------------------------
# 	   Coordinate                Previous        Force       Change         New
# 	   ----------                --------       ------       ------       ------
# 	    1 R(1,2)          =      1.159578    -0.132329     0.010133     1.169711
# 	    2 R(1,3)          =      2.365660    -0.029437     0.133826     2.499485
# 	    3 R(1,4)          =      2.630598     0.111524     0.174093     2.804691
# 	    4 R(2,3)          =      1.699170    -0.190056    -0.106715     1.592455
# 	    5 R(2,4)          =      2.455059    -0.149826    -0.124082     2.330977
# 	    6 R(3,4)          =      1.158238     0.014629     0.023856     1.182094
# 	    7 R(3,5)          =      1.152256    -0.311985    -0.065342     1.086914
# 	    8 B(1,2,3)        =    110.259651     0.001483    18.716713   128.976364
# 	    9 B(1,2,4)        =     85.447826     0.001335    15.810301   101.258127
# 	   10 B(1,3,2)        =     27.377163    -0.000541    -6.042748    21.334415
# 	   11 B(1,3,4)        =     89.813764     0.000617     2.334575    92.148339
# 	   12 B(1,4,2)        =     26.066468    -0.000322    -1.922550    24.143918
# 	   13 B(1,4,3)        =     64.063717    -0.000547    -1.120789    62.942927
# 	   14 B(2,1,3)        =     42.363187    -0.000942   -12.673965    29.689221
# 	   15 B(2,1,4)        =     68.485706    -0.001013   -13.887751    54.597955
# 	   16 B(2,3,4)        =    117.190927     0.000076    -3.708173   113.482754
# 	   17 B(2,3,5)        =    113.886909     0.000177     0.248957   114.135866
# 	   18 B(2,4,3)        =     37.997249    -0.000225     0.801761    38.799010
# 	   19 B(3,1,4)        =     26.122519    -0.000070    -1.213785    24.908734
# 	   20 B(3,2,4)        =     24.811824     0.000148     2.906412    27.718237
# 	   21 B(4,3,5)        =    128.922164    -0.000253     3.459216   132.381380
# 	   22 L(1,3,5)        =    141.264072    -0.000364    -5.793790   135.470281
# 	   23 l(1,3,5)        =    180.000000     0.000000     0.000000   180.000000
# 	   24 D(1,2,3,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   25 D(1,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   26 D(1,2,4,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   27 D(1,3,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   28 D(1,3,4,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   29 D(1,4,2,3)      =    180.000000     0.000000     0.000000   180.000000
# 	   30 D(1,4,3,2)      =      0.000000     0.000000     0.000000     0.000000
# 	   31 D(1,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   32 D(2,1,3,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   33 D(2,1,4,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   34 D(2,3,1,4)      =    180.000000     0.000000     0.000000   180.000000
# 	   35 D(2,4,1,3)      =      0.000000     0.000000     0.000000     0.000000
# 	   36 D(2,4,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	   37 D(3,1,2,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   38 D(3,2,1,4)      =      0.000000     0.000000     0.000000     0.000000
# 	   39 D(4,2,3,5)      =    180.000000     0.000000     0.000000   180.000000
# 	 ---------------------------------------------------------------------------
# 	Successfully symmetrized geometry.
#
#   ==> Convergence Check <==
#
#   Measures of convergence in internal coordinates in au.
#   Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#   ---------------------------------------------------------------------------------------------
#    Step     Total Energy     Delta E     MAX Force     RMS Force      MAX Disp      RMS Disp
#   ---------------------------------------------------------------------------------------------
#     Convergence Criteria    1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
#   ---------------------------------------------------------------------------------------------
#      49    -205.53815670   -1.32e-02      3.79e-02      1.01e-02 o    3.29e-01      1.25e-01 o  ~
#   ---------------------------------------------------------------------------------------------
#
# 	Writing optimization data to binary file.
# 	Structure for next step:
# 	Cartesian Geometry (in Angstrom)
# 	    N    -0.0210833898  -1.5678023397   0.0000000000
# 	    C    -0.7135769859  -0.6251059593   0.0000000000
# 	    C    -0.3088586236   0.9150615168   0.0000000000
# 	    O     0.8594473006   1.0950830721   0.0000000000
# 	    H    -1.1552309018   1.5969969747   0.0000000000
# 			--------------------------
# 			 OPTKING Finished Execution
# 			--------------------------
#
#     Structure for next step:
#     Molecular point group: cs
#     Full point group: Cs
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     N           -0.021411645884    -1.579631427740     0.000000000000
#     C           -0.713905244748    -0.636935043660     0.000000000000
#     C           -0.309186880861     0.903232438577     0.000000000000
#     O            0.859119047900     1.083253994564     0.000000000000
#     H           -1.155559162351     1.585167899091     0.000000000000
#
# 	Cleaning optimization helper files.
#
# PsiException: Could not converge geometry optimization in 50 iterations.
# ---------------------------------------------------------------------------
# OptimizationConvergenceError              Traceback (most recent call last)
# /var/folders/tm/l9n3216d1nd4rx41smlqm5pc0000gn/T/ipykernel_1438/1693155860.py in <module>
#       1 psi4.set_memory('8GB')
# ----> 2 psi4.optimize('scf/cc-pvdz', molecule=mol)
#
# ~/opt/anaconda3/envs/MDSAPT/lib/python3.8/site-packages/psi4/driver/driver.py in optimize(name, **kwargs)
#    1444
#    1445     optstash.restore()
# -> 1446     raise OptimizationConvergenceError("""geometry optimization""", n - 1, wfn)
#    1447
#    1448
#
# OptimizationConvergenceError: Could not converge geometry optimization in 50 iterations.
